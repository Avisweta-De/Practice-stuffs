# %% [markdown]
# <a href="https://colab.research.google.com/github/Avisweta-De/Practice-stuffs/blob/main/Pandas_Profiling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas==1.5.3 numpy==1.23.5 ydata-profiling==4.1.2

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import seaborn as sns

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b027f93-d7d2-49aa-b144-971846e8beed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b027f93-d7d2-49aa-b144-971846e8beed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('movies.csv')
print(df.head())
# Out:
#           id              primaryTitle             originalTitle   type  \
# 0  tt0111161  The Shawshank Redemption  The Shawshank Redemption  movie
# 1  tt0068646             The Godfather             The Godfather  movie
# 2  tt0468569           The Dark Knight           The Dark Knight  movie
# 3  tt0071562     The Godfather Part II     The Godfather Part II  movie
# 4  tt0050083              12 Angry Men              12 Angry Men  movie
#
#                                          description  \
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...
#
#                                      url  \
# 0  https://www.imdb.com/title/tt0111161/
# 1  https://www.imdb.com/title/tt0068646/
# 2  https://www.imdb.com/title/tt0468569/
# ...

# %%
# Generate report
profile = ProfileReport(df, title="TOP 250 IMDB movies report", explorative=True)

profile.to_file(output_file='moviesreport.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
