# %% [markdown]
# <a href="https://colab.research.google.com/github/Avisweta-De/Practice-stuffs/blob/main/Pandas_Profiling_fresh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numba==0.56.4
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 23.3 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
# !pip install ydata-profiling==4.6.4 pandas==2.1.3 numba==0.57.1

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import seaborn as sns

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-812e93a5-426c-418d-8778-bcdcc220efdc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-812e93a5-426c-418d-8778-bcdcc220efdc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('movies.csv')
print(df.head())
# Out:
#           id              primaryTitle             originalTitle   type  \
# 0  tt0111161  The Shawshank Redemption  The Shawshank Redemption  movie
# 1  tt0068646             The Godfather             The Godfather  movie
# 2  tt0468569           The Dark Knight           The Dark Knight  movie
# 3  tt0071562     The Godfather Part II     The Godfather Part II  movie
# 4  tt0050083              12 Angry Men              12 Angry Men  movie
#
#                                          description  \
# 0  A banker convicted of uxoricide forms a friend...
# 1  The aging patriarch of an organized crime dyna...
# 2  When a menace known as the Joker wreaks havoc ...
# 3  The early life and career of Vito Corleone in ...
# 4  The jury in a New York City murder trial is fr...
#
#                                      url  \
# 0  https://www.imdb.com/title/tt0111161/
# 1  https://www.imdb.com/title/tt0068646/
# 2  https://www.imdb.com/title/tt0468569/
# ...

# %%
# Generate report
profile = ProfileReport(df, title="TOP 250 IMDB movies report", explorative=True)

profile.to_file(output_file='moviesreport.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/model/typeset.py:125: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   not pdt.is_categorical_dtype(series)
# /usr/local/lib/python3.11/dist-packages/ydata_profiling/model/typeset.py:208: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_valid_dtype = pdt.is_categorical_dtype(series) and not pdt.is_bool_dtype(
# ...
